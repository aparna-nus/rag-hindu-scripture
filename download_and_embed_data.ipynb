# %% [markdown]
# # RAG × Groq Llama 3.1 — Hindu Scripture

# %% [markdown]
# **What this notebook does**
# - Downloads Corpus(Bhagavad Gita, Rig Veda, Upanishads)
# - Creates embeddings for the data and saves chunks locally
#
# > Created: 2025-11-11

# %% [markdown]
# ## 1) Setup

# %%
# !pip3 install -q sentence-transformers rank-bm25 requests numpy scipy beautifulsoup4 lxml
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 555.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
# If running the first time, uncomment these installs.
# %pip install -q sentence-transformers rank-bm25 requests numpy scipy
# Optional (speeds up BLAS on some systems): 
# %pip install -q accelerate

import os, sys, json, math, time, textwrap, traceback, random
from dataclasses import dataclass
from typing import List, Dict, Any, Tuple
import numpy as np
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
import requests

# ---- Configure Groq API ----
# 1) Set your key here (or export as an env var before starting Jupyter):
# os.environ['GROQ_API_KEY'] = "paste-your-key-here"
GROQ_API_KEY = os.getenv("GROQ_API_KEY", None)

# Pick a Groq model (both are free tier as of writing)
GROQ_MODEL = "llama-3.1-8b-instant"  # alt: "llama-3.1-70b-versatile"

print("Groq key present?", bool(GROQ_API_KEY))
print("Using model:", GROQ_MODEL)
# Out:
# Groq key present? True
# Using model: llama-3.1-8b-instant

# %% [markdown]
# ## Data Download (gita)

# %%
#  example schema structure for data, enabling scraping from Vedas/Upanishads/Gita
example_schema = {
  "id": "RV.1.001.001",                # stable ID for your corpus
  "work": "Rig Veda",
  "collection": "Vedas",               # optional: Vedas/Upanishads/Gita
  "canonical_ref": "RV 1.1.1",         # human-facing reference
  "book": 1,                           # Rig: mandala/book number
  "hymn": 1,                           # Rig: hymn number (sukta)
  "verse": 1,                          # Rig: verse within hymn (ṛc)
  "upanishad": 0,                   # Upanishads: name string if used
  "chapter": 0,                     # Upanishads/Gita: chapter if applicable
  "section": 0,                     # khanda/anuvaka etc.
  "translator": "R. T. H. Griffith (1896) — Public Domain",
  "year": 1896,
  "license": "Public Domain",
  "source_url": "https://…",
  "lang": "en",
  "text": "Agni I invoke, the household priest…"
}

# %%
# --- Robust fetch & poem-line parser for Sacred-Texts (Arnold PD) ---
# If needed: %pip install -q beautifulsoup4 lxml

import re, json, time, pathlib, requests
from bs4 import BeautifulSoup, NavigableString

BASE = "https://www.sacred-texts.com/hin/gita/"
CHAPTERS = [f"bg{str(i).zfill(2)}.htm" for i in range(1, 19)]
OUT_DIR = pathlib.Path("data"); OUT_DIR.mkdir(exist_ok=True, parents=True)
OUT_PATH = OUT_DIR / "bg_arnold.jsonl"

HDRS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

def fetch(url, tries=3, sleep=0.8):
    for _ in range(tries):
        r = requests.get(url, timeout=30, headers=HDRS)
        if r.ok: return r.text
        time.sleep(sleep)
    r.raise_for_status()

def clean(s: str) -> str:
    return re.sub(r"\s+", " ", s).strip(" \u00a0")

def looks_like_heading(s: str) -> bool:
    s2 = s.strip()
    # skip chapter titles / subtitles / navigation
    if len(s2) <= 2: return True
    if s2.upper() == s2 and any(w.isalpha() for w in s2) and len(s2) < 60: return True
    if re.match(r"^(chapter|book)\b", s2, re.I): return True
    if re.match(r"^\(?[IVXLC]+\)?\.*$", s2): return True  # roman numerals
    if re.match(r"^\d+\.$", s2): return True              # stray number
    if "sacred-texts.com" in s2.lower(): return True
    return False

def parse_poem_lines(html: str) -> list[str]:
    soup = BeautifulSoup(html, "lxml")
    for tag in soup.select("script, style, header, footer, nav"): tag.decompose()

    body = soup.find("body") or soup
    # Heuristic: use the largest center/blockquote/p blocks (poem sections usually sit there)
    candidates = body.find_all(["center","blockquote","div","p"])
    lines = []
    for el in candidates:
        # split on <br> boundaries by walking strings
        chunk_lines = []
        buf = []
        for node in el.descendants:
            if isinstance(node, NavigableString):
                buf.append(str(node))
            elif getattr(node, "name", None) == "br":
                txt = clean(" ".join(buf))
                if txt:
                    chunk_lines.append(txt)
                buf = []
        # flush tail
        tail = clean(" ".join(buf))
        if tail:
            chunk_lines.append(tail)
        # filter headings / nav
        chunk_lines = [ln for ln in chunk_lines if not looks_like_heading(ln)]
        # keep only sections that look poem-y (multiple shortish lines)
        if sum(len(x) for x in chunk_lines) > 120 and len(chunk_lines) >= 5:
            lines.extend(chunk_lines)

    # if nothing found, fallback to full text split on double spaces / periods
    if not lines:
        full = clean(body.get_text(" ", strip=True))
        parts = [p.strip() for p in re.split(r"\s{2,}|\n+", full) if p.strip()]
        lines = [p for p in parts if not looks_like_heading(p)]

    # final cleaning: drop duplicate nav tails
    lines = [ln for ln in lines if len(ln) > 1]
    return lines

# ---- Download & parse all chapters into sequentially-numbered "verses" ----
full = []
for chap, fname in enumerate(CHAPTERS, start=1):
    url = BASE + fname
    print("Fetching", url)
    html = fetch(url)
    poem = parse_poem_lines(html)

    # DEBUG: show first 8 lines so you can eyeball quality
    print(f"  → poem lines parsed: {len(poem)}")
    for preview in poem[:8]:
        print("     ·", preview[:100])

    # assign sequential verse numbers per chapter
    for i, text in enumerate(poem, start=1):
        full.append({
            "canon_id": f"BG {chap}.{i}",
            "work": "Bhagavad Gita",
            "chapter": chap,
            "verse": i,
            "translator": "Sir Edwin Arnold (1885) — Public Domain",
            "license": "Public Domain",
            "source": url,
            "text": text
        })

print("Chapters parsed:", len({x['chapter'] for x in full}))
print("Total verse-units:", len(full))
print("Sample:", full[:3])

with open(OUT_PATH, "w", encoding="utf-8") as f:
    for e in full:
        f.write(json.dumps(e, ensure_ascii=False) + "\n")

print("Saved to", OUT_PATH)
# Out:
# Fetching https://www.sacred-texts.com/hin/gita/bg01.htm
#   → poem lines parsed: 133
#      · Dhritirashtra. Ranged thus for battle on the sacred plain-
#      · On Kurukshetra- say, Sanjaya! say
#      · What wrought my people, and the Pandavas?
#      · Sanjaya. When he beheld the host of Pandavas,
#      · Raja Duryodhana to Drona drew,
#      · And spake these words: "Ah, Guru! see this line,
#      · How vast it is of Pandu fighting-men,
#      · Embattled by the son of Drupada,
# Fetching https://www.sacred-texts.com/hin/gita/bg02.htm
#   → poem lines parsed: 270
#      · Sanjaya. Him, filled with such compassion and such grief,
#      · With eyes tear-dimmed, despondent, in stern words
#      · The Driver, Madhusudan, thus addressed:
#      · Krishna. How hath this weakness taken thee?
#      · Whence springs
#      · The inglorious trouble, shameful to the brave,
#      · Barring the path of virtue? Nay, Arjun!
#      · Forbid thyself to feebleness! it mars
# Fetching https://www.sacred-texts.com/hin/gita/bg03.htm
#   → poem lines parsed: 142
#      · Arjuna. Thou whom all mortals praise, Janardana!
#      · If meditation be a nobler thing
#      · Than action, wherefore, then, great Kesava!
#      · Dost thou impel me to this dreadful fight?
#      · Now am I by thy doubtful speech disturbed!
#      · Tell me one thing, and tell me certainly;
#      · By what road shall I find the better end?
#      · Krishna. I told thee, blameless Lord! there be paths
# Fetching https://www.sacred-texts.com/hin/gita/bg04.htm
#   → poem lines parsed: 151
#      · Krishna. This deathless Yoga, this deep union,
#      · I taught Vivaswata, the Lord of Light;
#      · Vivaswata to Manu gave it; he
#      · To Ikshwaku; so passed it down the line
#      · Of all my royal Rishis. Then, with years,
#      · The truth grew dim and perished, noble Prince!
#      · Now once again to thee it is declared-
#      · This ancient lore, this mystery supreme-
# Fetching https://www.sacred-texts.com/hin/gita/bg05.htm
#   → poem lines parsed: 102
#      · Arjuna. Yet, Krishna at the one time thou dost laud
#      · Surcease of works, and, at another time,
#      · Service through work. Of these twain plainly tell
#      · Which is the better way?
#      · Krishna. To cease from works
#      · Is well, and to do works in holiness
#      · Is well; and both conduct to bliss supreme;
#      · But of these twain the better way is his
# Fetching https://www.sacred-texts.com/hin/gita/bg06.htm
#   → poem lines parsed: 160
#      · Krishna. Therefore, who doeth work rightful to do,
#      · Not seeking gain from work, that man, O Prince!
#      · Is Sanyasi and Yogi- both in one
#      · And he is neither who lights not the flame
#      · Of sacrifice, nor setteth hand to task.
#      · Regard as true Renouncer him that makes
#      · Worship by work, for who renounceth not
#      · Works not as Yogin. So is that well said:
# Fetching https://www.sacred-texts.com/hin/gita/bg07.htm
#   → poem lines parsed: 94
#      · Krishna. Learn now, dear Prince! how, if thy soul be set
#      · Ever on Me- still exercising Yog,
#      · Still making Me thy Refuge- thou shalt come
#      · Most surely unto perfect hold of Me.
#      · I will declare to thee that utmost lore,
#      · Whole and particular, which, when thou knowest,
#      · Leaveth no more to know here in this world.
#      · These be my lower Nature; learn the higher,
# Fetching https://www.sacred-texts.com/hin/gita/bg08.htm
#   → poem lines parsed: 72
#      · Arjuna. Who is that BRAHMA? What that Soul of Souls,
#      · The ADHYATMAN? What, Thou Best of All!
#      · Thy work, the KARMA? Tell me what it is
#      · Thou namest ADHIBHUTA? What again
#      · Means ADHIDAIVA? Yea, and how it comes
#      · Thou canst be ADHIYAJNA in thy flesh?
#      · Slayer of Madhu! Further, make me know
#      · How good men find thee in the hour of death?
# Fetching https://www.sacred-texts.com/hin/gita/bg09.htm
#   → poem lines parsed: 102
#      · Krishna. Now will I open unto thee- whose heart
#      · Rejects not- that last lore, deepest-concealed,
#      · That farthest secret of My Heavens and Earths,
#      · Which but to know shall set thee free from ills,-
#      · A royal lore! a Kingly mystery!
#      · Yea! for the soul such light as purgeth it
#      · From every sin; a light of holiness
#      · With inmost splendour shining; plain to see;
# Fetching https://www.sacred-texts.com/hin/gita/bg10.htm
#   → poem lines parsed: 119
#      · Krishna. Hear farther yet, thou Long-Armed Lord! these latest
#      · words I say-
#      · Uttered to bring thee bliss and peace, who lovest Me alway-
#      · Not the great company of gods nor kingly Rishis know
#      · My Nature, Who have made the gods and Rishis long ago;
#      · He only knoweth- only he is free of sin, and wise,
#      · Who seeth Me, Lord of the Worlds, with faith-enlightened eyes,
#      · Unborn, undying, unbegun. Whatever Natures be
# Fetching https://www.sacred-texts.com/hin/gita/bg11.htm
#   → poem lines parsed: 347
#      · Arjuna. This, for my soul's peace, have I heard from Thee,
#      · The unfolding of the Mystery Supreme
#      · Named Adhyatman; comprehending which,
#      · My darkness is dispelled; for now I know-
#      · O Lotus-eyed!- whence is the birth of men,
#      · And whence their death, and what the majesties
#      · Of Thine immortal rule. Fain would I see,
#      · As thou Thyself declar'st it, Sovereign Lord!
# Fetching https://www.sacred-texts.com/hin/gita/bg12.htm
#   → poem lines parsed: 69
#      · Arjuna. Lord! of the men who serve Thee- true in heart-
#      · As God revealed; and of the men who serve,
#      · Worshipping Thee Unrevealed, Unbodied, Far,
#      · Which take the better way of faith and life?
#      · Krishna. Whoever serve Me- as I show Myself-
#      · Constantly true, in full devotion fixed,
#      · Those hold I very holy. But who serve-
#      · Worshipping Me The One, The Invisible,
# Fetching https://www.sacred-texts.com/hin/gita/bg13.htm
#   → poem lines parsed: 121
#      · Arjuna. Now would I hear, O gracious Kesava!
#      · Of Life which seems, and Soul beyond, which sees,
#      · And what it is we know- or think to know.
#      · Krishna. Yea! Son of Kunti! for this flesh ye see
#      · Is Kshetra, is the field where Life disports;
#      · And that which views and knows it is the Soul,
#      · Kshetrajna. In all "fields," thou Indian prince!
#      · I am Kshetrajna. I am what surveys!
# Fetching https://www.sacred-texts.com/hin/gita/bg14.htm
#   → poem lines parsed: 88
#      · Krishna. Yet farther will I open unto thee
#      · This wisdom of all wisdoms, uttermost,
#      · The which possessing, all My saints have passed
#      · To perfectness. On such high verities
#      · Reliant, rising into fellowship
#      · With Me, they are not born again at birth
#      · Of Kalpas, nor at Pralyas suffer change!
#      · This Universe the womb is where I plant
# Fetching https://www.sacred-texts.com/hin/gita/bg15.htm
#   → poem lines parsed: 59
#      · Krishna. Men call the Aswattha,- the Banyan-tree,-
#      · Which hath its boughs beneath, its roots above,-
#      · The ever-holy tree. Yea! for its leaves
#      · Are green and waving hymns which whisper Truth!
#      · Who knows the Aswattha, knows Veds, and all.
#      · Its branches shoot to heaven and sink to earth,
#      · Even as the deeds of men, which take their birth
#      · From qualities: its silver sprays and blooms,
# Fetching https://www.sacred-texts.com/hin/gita/bg16.htm
#   → poem lines parsed: 79
#      · Krishna. Fearlessness, singleness of soul, the wilL
#      · Always to strive for wisdom; opened hand
#      · And governed appetites; and piety,
#      · And love of lonely study; humbleness,
#      · Uprightness, heed to injure nought which lives,
#      · Truthfulness, slowness unto wrath, a mind
#      · That lightly letteth go what others prize;
#      · And equanimity, and charity
# Fetching https://www.sacred-texts.com/hin/gita/bg17.htm
#   → poem lines parsed: 62
#      · Arjuna. If men forsake the holy ordinance,
#      · Heedless of Shastras, yet keep faith at heart
#      · And worship, what shall be the state of those,
#      · Great Krishna! Sattwan, Rajas, Tamas? Say!
#      · Krishna. Threefold the faith is of mankind, and springs
#      · From those three qualities,- becoming "true,"
#      · Or "passion-stained," or "dark," as thou shalt hear!
#      · The faith of each believer, Indian Prince!
# Fetching https://www.sacred-texts.com/hin/gita/bg18.htm
#   → poem lines parsed: 266
#      · Arjuna. Fain would I better know, Thou Glorious One!
#      · The very truth- Heart's Lord!- of Sannyas,
#      · Abstention; and Renunciation, Lord!
#      · Tyaga; and what separates these twain!
#      · Krishna. The poets rightly teach that Sannyas
#      · Is the foregoing of all acts which spring
#      · Out of desire; and their wisest say
#      · Tyaga is renouncing fruit of acts.
# Chapters parsed: 18
# Total verse-units: 2436
# Sample: [{'canon_id': 'BG 1.1', 'work': 'Bhagavad Gita', 'chapter': 1, 'verse': 1, 'translator': 'Sir Edwin Arnold (1885) — Public Domain', 'license': 'Public Domain', 'source': 'https://www.sacred-texts.com/hin/gita/bg01.htm', 'text': 'Dhritirashtra. Ranged thus for battle on the sacred plain-'}, {'canon_id': 'BG 1.2', 'work': 'Bhagavad Gita', 'chapter': 1, 'verse': 2, 'translator': 'Sir Edwin Arnold (1885) — Public Domain', 'license': 'Public Domain', 'source': 'https://www.sacred-texts.com/hin/gita/bg01.htm', 'text': 'On Kurukshetra- say, Sanjaya! say'}, {'canon_id': 'BG 1.3', 'work': 'Bhagavad Gita', 'chapter': 1, 'verse': 3, 'translator': 'Sir Edwin Arnold (1885) — Public Domain', 'license': 'Public Domain', 'source': 'https://www.sacred-texts.com/hin/gita/bg01.htm', 'text': 'What wrought my people, and the Pandavas?'}]
# Saved to data/bg_arnold.jsonl

# %%
# ===== Upanishads (SBE 1 & 15) → download, parse, and save JSONL shards =====
# If needed:  %pip install -q beautifulsoup4 lxml
import re, json, time, pathlib, requests, urllib.parse
from bs4 import BeautifulSoup, NavigableString

BASES = [
    # Index pages for Max Müller SBE translations (Public Domain)
    "https://www.sacred-texts.com/hin/sbe01/index.htm",   # Brihadaranyaka, Chandogya, etc.
    "https://www.sacred-texts.com/hin/sbe15/index.htm",   # Isa, Kena, Katha, Prashna, Mundaka, Mandukya, etc.
]
OUT_ROOT = pathlib.Path("data/upanishads_sbe")
OUT_ROOT.mkdir(parents=True, exist_ok=True)

HDRS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

def fetch(url, tries=3, sleep=0.7):
    for _ in range(tries):
        r = requests.get(url, headers=HDRS, timeout=30)
        if r.ok:
            return r.text
        time.sleep(sleep)
    r.raise_for_status()

def abs_url(base, href):
    return urllib.parse.urljoin(base, href)

def clean(s: str) -> str:
    return re.sub(r"\s+", " ", s).strip(" \u00a0")

# very loose heading detector to skip navigation and headers
def looks_like_heading(s: str) -> bool:
    s2 = s.strip()
    if not s2: return True
    if len(s2) <= 2: return True
    if re.match(r"^(chapter|book|section|khanda|adhy[aā]ya|lesson)\b", s2, re.I): return True
    if re.match(r"^[IVXLC]+\.*$", s2.strip(), re.I): return True
    if "sacred-texts.com" in s2.lower(): return True
    return False

def guess_upanishad_slug(title_or_url: str) -> str:
    t = title_or_url.lower()
    for key in ["isa", "kena", "katha", "prashna", "prasna", "mundaka", "mandukya", "taittiriya", "aitareya",
                "kaushitaki", "kau", "kaushit", "svetasvatara", "svesh", "svet", "brihadaranyaka", "brhad", "chandogya",
                "chandogya", "katha", "katha2", "katha-upanishad", "upanishad"]:
        if key in t:
            return re.sub(r"[^a-z0-9]+","_", key)
    # fallback: last path piece
    leaf = title_or_url.rsplit("/",1)[-1]
    leaf = leaf.split(".")[0]
    return re.sub(r"[^a-z0-9]+","_", leaf)

def extract_title(soup: BeautifulSoup) -> str:
    for tag in ["h1","h2","title","center","b","strong"]:
        el = soup.find(tag)
        if el and el.get_text(strip=True):
            return clean(el.get_text(" ", strip=True))
    return "Upanishad"

def parse_page_to_lines(html: str) -> list[str]:
    soup = BeautifulSoup(html, "lxml")
    for t in soup.select("script, style, header, footer, nav"): t.decompose()
    body = soup.find("body") or soup
    # split on <br> and <p>, skip headings
    lines = []
    for el in body.find_all(["p","div","blockquote","center"]):
        buf = []
        for node in el.descendants:
            if isinstance(node, NavigableString):
                buf.append(str(node))
            elif getattr(node, "name", None) == "br":
                txt = clean(" ".join(buf))
                if txt and not looks_like_heading(txt):
                    lines.append(txt)
                buf = []
        tail = clean(" ".join(buf))
        if tail and not looks_like_heading(tail):
            lines.append(tail)
    # light prune
    lines = [ln for ln in lines if len(ln) > 1]
    return lines

# Crawl index pages → follow .htm links in the same directory tree
visited, pages = set(), []
for idx_url in BASES:
    idx_html = fetch(idx_url)
    soup = BeautifulSoup(idx_html, "lxml")
    base_dir = idx_url.rsplit("/",1)[0] + "/"
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if not href.lower().endswith(".htm"): continue
        url = abs_url(idx_url, href)
        if not url.startswith(base_dir): continue
        if "index" in url.lower(): continue
        pages.append(url)

pages = sorted(set(pages))
print(f"Discovered {len(pages)} candidate pages from SBE indices.")

# Group pages by upanishad slug (heuristic)
groups = {}
for url in pages:
    slug = guess_upanishad_slug(url)
    groups.setdefault(slug, []).append(url)

print("Grouped into", len(groups), "upanishad buckets (heuristic).")

# Parse each bucket → sequentially numbered units per upanishad
for slug, urls in groups.items():
    urls = sorted(urls)
    out_path = OUT_ROOT / f"{slug}.jsonl"
    items = []
    unit_no = 0
    for url in urls:
        try:
            html = fetch(url)
            lines = parse_page_to_lines(html)
            # Debug preview
            print(f"[{slug}] {url} → {len(lines)} lines")
            for ln in lines:
                unit_no += 1
                items.append({
                    "id": f"{slug}.{unit_no:04d}",
                    "collection": "Upanishads",
                    "work": slug,                      # normalized slug for filtering
                    "upanishad": extract_title(BeautifulSoup(html, "lxml")),
                    "canonical_ref": f"{slug.upper()} {unit_no}",
                    "chapter": None, "section": None, "verse": unit_no,
                    "translator": "Max Müller (Sacred Books of the East) — Public Domain",
                    "year": 1884,
                    "license": "Public Domain",
                    "source_url": url,
                    "lang": "en",
                    "text": ln
                })
        except Exception as e:
            print(f"  !! Failed: {url} → {e}")
    if not items:
        print(f"  !! No items for {slug}, skipping.")
        continue
    with open(out_path, "w", encoding="utf-8") as f:
        for it in items:
            f.write(json.dumps(it, ensure_ascii=False) + "\n")
    print(f"[OK] Saved {len(items)} units → {out_path}")
# Out:
# Discovered 367 candidate pages from SBE indices.
# Grouped into 365 upanishad buckets (heuristic).
# [errata] https://www.sacred-texts.com/hin/sbe01/errata.htm → 1 lines
# [errata] https://www.sacred-texts.com/hin/sbe15/errata.htm → 2 lines
# [OK] Saved 3 units → data/upanishads_sbe/errata.jsonl
# [pageidx] https://www.sacred-texts.com/hin/sbe01/pageidx.htm → 1 lines
# [pageidx] https://www.sacred-texts.com/hin/sbe15/pageidx.htm → 1 lines
# [OK] Saved 2 units → data/upanishads_sbe/pageidx.jsonl
# [sbe01000] https://www.sacred-texts.com/hin/sbe01/sbe01000.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01000.jsonl
# [sbe01001] https://www.sacred-texts.com/hin/sbe01/sbe01001.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe01001.jsonl
# [sbe01002] https://www.sacred-texts.com/hin/sbe01/sbe01002.htm → 121 lines
# [OK] Saved 121 units → data/upanishads_sbe/sbe01002.jsonl
# [sbe01003] https://www.sacred-texts.com/hin/sbe01/sbe01003.htm → 79 lines
# [OK] Saved 79 units → data/upanishads_sbe/sbe01003.jsonl
# [sbe01004] https://www.sacred-texts.com/hin/sbe01/sbe01004.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01004.jsonl
# [sbe01005] https://www.sacred-texts.com/hin/sbe01/sbe01005.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01005.jsonl
# [sbe01006] https://www.sacred-texts.com/hin/sbe01/sbe01006.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01006.jsonl
# [sbe01007] https://www.sacred-texts.com/hin/sbe01/sbe01007.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01007.jsonl
# [sbe01008] https://www.sacred-texts.com/hin/sbe01/sbe01008.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01008.jsonl
# [sbe01009] https://www.sacred-texts.com/hin/sbe01/sbe01009.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01009.jsonl
# [sbe01010] https://www.sacred-texts.com/hin/sbe01/sbe01010.htm → 36 lines
# [OK] Saved 36 units → data/upanishads_sbe/sbe01010.jsonl
# [sbe01011] https://www.sacred-texts.com/hin/sbe01/sbe01011.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01011.jsonl
# [sbe01012] https://www.sacred-texts.com/hin/sbe01/sbe01012.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01012.jsonl
# [sbe01013] https://www.sacred-texts.com/hin/sbe01/sbe01013.htm → 31 lines
# [OK] Saved 31 units → data/upanishads_sbe/sbe01013.jsonl
# [sbe01014] https://www.sacred-texts.com/hin/sbe01/sbe01014.htm → 61 lines
# [OK] Saved 61 units → data/upanishads_sbe/sbe01014.jsonl
# [sbe01015] https://www.sacred-texts.com/hin/sbe01/sbe01015.htm → 51 lines
# [OK] Saved 51 units → data/upanishads_sbe/sbe01015.jsonl
# [sbe01016] https://www.sacred-texts.com/hin/sbe01/sbe01016.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01016.jsonl
# [sbe01017] https://www.sacred-texts.com/hin/sbe01/sbe01017.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01017.jsonl
# [sbe01018] https://www.sacred-texts.com/hin/sbe01/sbe01018.htm → 17 lines
# [OK] Saved 17 units → data/upanishads_sbe/sbe01018.jsonl
# [sbe01019] https://www.sacred-texts.com/hin/sbe01/sbe01019.htm → 70 lines
# [OK] Saved 70 units → data/upanishads_sbe/sbe01019.jsonl
# [sbe01020] https://www.sacred-texts.com/hin/sbe01/sbe01020.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01020.jsonl
# [sbe01021] https://www.sacred-texts.com/hin/sbe01/sbe01021.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01021.jsonl
# [sbe01022] https://www.sacred-texts.com/hin/sbe01/sbe01022.htm → 26 lines
# [OK] Saved 26 units → data/upanishads_sbe/sbe01022.jsonl
# [sbe01023] https://www.sacred-texts.com/hin/sbe01/sbe01023.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe01023.jsonl
# [sbe01024] https://www.sacred-texts.com/hin/sbe01/sbe01024.htm → 43 lines
# [OK] Saved 43 units → data/upanishads_sbe/sbe01024.jsonl
# [sbe01025] https://www.sacred-texts.com/hin/sbe01/sbe01025.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01025.jsonl
# [sbe01026] https://www.sacred-texts.com/hin/sbe01/sbe01026.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01026.jsonl
# [sbe01027] https://www.sacred-texts.com/hin/sbe01/sbe01027.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01027.jsonl
# [sbe01028] https://www.sacred-texts.com/hin/sbe01/sbe01028.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01028.jsonl
# [sbe01029] https://www.sacred-texts.com/hin/sbe01/sbe01029.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe01029.jsonl
# [sbe01030] https://www.sacred-texts.com/hin/sbe01/sbe01030.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01030.jsonl
# [sbe01031] https://www.sacred-texts.com/hin/sbe01/sbe01031.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01031.jsonl
# [sbe01032] https://www.sacred-texts.com/hin/sbe01/sbe01032.htm → 17 lines
# [OK] Saved 17 units → data/upanishads_sbe/sbe01032.jsonl
# [sbe01033] https://www.sacred-texts.com/hin/sbe01/sbe01033.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01033.jsonl
# [sbe01034] https://www.sacred-texts.com/hin/sbe01/sbe01034.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01034.jsonl
# [sbe01035] https://www.sacred-texts.com/hin/sbe01/sbe01035.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01035.jsonl
# [sbe01036] https://www.sacred-texts.com/hin/sbe01/sbe01036.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01036.jsonl
# [sbe01037] https://www.sacred-texts.com/hin/sbe01/sbe01037.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01037.jsonl
# [sbe01038] https://www.sacred-texts.com/hin/sbe01/sbe01038.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01038.jsonl
# [sbe01039] https://www.sacred-texts.com/hin/sbe01/sbe01039.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01039.jsonl
# [sbe01040] https://www.sacred-texts.com/hin/sbe01/sbe01040.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01040.jsonl
# [sbe01041] https://www.sacred-texts.com/hin/sbe01/sbe01041.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01041.jsonl
# [sbe01042] https://www.sacred-texts.com/hin/sbe01/sbe01042.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01042.jsonl
# [sbe01043] https://www.sacred-texts.com/hin/sbe01/sbe01043.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01043.jsonl
# [sbe01044] https://www.sacred-texts.com/hin/sbe01/sbe01044.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01044.jsonl
# [sbe01045] https://www.sacred-texts.com/hin/sbe01/sbe01045.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01045.jsonl
# [sbe01046] https://www.sacred-texts.com/hin/sbe01/sbe01046.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01046.jsonl
# [sbe01047] https://www.sacred-texts.com/hin/sbe01/sbe01047.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01047.jsonl
# [sbe01048] https://www.sacred-texts.com/hin/sbe01/sbe01048.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01048.jsonl
# [sbe01049] https://www.sacred-texts.com/hin/sbe01/sbe01049.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01049.jsonl
# [sbe01050] https://www.sacred-texts.com/hin/sbe01/sbe01050.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01050.jsonl
# [sbe01051] https://www.sacred-texts.com/hin/sbe01/sbe01051.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01051.jsonl
# [sbe01052] https://www.sacred-texts.com/hin/sbe01/sbe01052.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01052.jsonl
# [sbe01053] https://www.sacred-texts.com/hin/sbe01/sbe01053.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01053.jsonl
# [sbe01054] https://www.sacred-texts.com/hin/sbe01/sbe01054.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01054.jsonl
# [sbe01055] https://www.sacred-texts.com/hin/sbe01/sbe01055.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01055.jsonl
# [sbe01056] https://www.sacred-texts.com/hin/sbe01/sbe01056.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe01056.jsonl
# [sbe01057] https://www.sacred-texts.com/hin/sbe01/sbe01057.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01057.jsonl
# [sbe01058] https://www.sacred-texts.com/hin/sbe01/sbe01058.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe01058.jsonl
# [sbe01059] https://www.sacred-texts.com/hin/sbe01/sbe01059.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01059.jsonl
# [sbe01060] https://www.sacred-texts.com/hin/sbe01/sbe01060.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01060.jsonl
# [sbe01061] https://www.sacred-texts.com/hin/sbe01/sbe01061.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01061.jsonl
# [sbe01062] https://www.sacred-texts.com/hin/sbe01/sbe01062.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01062.jsonl
# [sbe01063] https://www.sacred-texts.com/hin/sbe01/sbe01063.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01063.jsonl
# [sbe01064] https://www.sacred-texts.com/hin/sbe01/sbe01064.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01064.jsonl
# [sbe01065] https://www.sacred-texts.com/hin/sbe01/sbe01065.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01065.jsonl
# [sbe01066] https://www.sacred-texts.com/hin/sbe01/sbe01066.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01066.jsonl
# [sbe01067] https://www.sacred-texts.com/hin/sbe01/sbe01067.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01067.jsonl
# [sbe01068] https://www.sacred-texts.com/hin/sbe01/sbe01068.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01068.jsonl
# [sbe01069] https://www.sacred-texts.com/hin/sbe01/sbe01069.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01069.jsonl
# [sbe01070] https://www.sacred-texts.com/hin/sbe01/sbe01070.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01070.jsonl
# [sbe01071] https://www.sacred-texts.com/hin/sbe01/sbe01071.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01071.jsonl
# [sbe01072] https://www.sacred-texts.com/hin/sbe01/sbe01072.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01072.jsonl
# [sbe01073] https://www.sacred-texts.com/hin/sbe01/sbe01073.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe01073.jsonl
# [sbe01074] https://www.sacred-texts.com/hin/sbe01/sbe01074.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01074.jsonl
# [sbe01075] https://www.sacred-texts.com/hin/sbe01/sbe01075.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01075.jsonl
# [sbe01076] https://www.sacred-texts.com/hin/sbe01/sbe01076.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01076.jsonl
# [sbe01077] https://www.sacred-texts.com/hin/sbe01/sbe01077.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01077.jsonl
# [sbe01078] https://www.sacred-texts.com/hin/sbe01/sbe01078.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01078.jsonl
# [sbe01079] https://www.sacred-texts.com/hin/sbe01/sbe01079.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01079.jsonl
# [sbe01080] https://www.sacred-texts.com/hin/sbe01/sbe01080.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01080.jsonl
# [sbe01081] https://www.sacred-texts.com/hin/sbe01/sbe01081.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01081.jsonl
# [sbe01082] https://www.sacred-texts.com/hin/sbe01/sbe01082.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01082.jsonl
# [sbe01083] https://www.sacred-texts.com/hin/sbe01/sbe01083.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01083.jsonl
# [sbe01084] https://www.sacred-texts.com/hin/sbe01/sbe01084.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01084.jsonl
# [sbe01085] https://www.sacred-texts.com/hin/sbe01/sbe01085.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01085.jsonl
# [sbe01086] https://www.sacred-texts.com/hin/sbe01/sbe01086.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01086.jsonl
# [sbe01087] https://www.sacred-texts.com/hin/sbe01/sbe01087.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01087.jsonl
# [sbe01088] https://www.sacred-texts.com/hin/sbe01/sbe01088.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01088.jsonl
# [sbe01089] https://www.sacred-texts.com/hin/sbe01/sbe01089.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01089.jsonl
# [sbe01090] https://www.sacred-texts.com/hin/sbe01/sbe01090.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01090.jsonl
# [sbe01091] https://www.sacred-texts.com/hin/sbe01/sbe01091.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01091.jsonl
# [sbe01092] https://www.sacred-texts.com/hin/sbe01/sbe01092.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01092.jsonl
# [sbe01093] https://www.sacred-texts.com/hin/sbe01/sbe01093.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01093.jsonl
# [sbe01094] https://www.sacred-texts.com/hin/sbe01/sbe01094.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe01094.jsonl
# [sbe01095] https://www.sacred-texts.com/hin/sbe01/sbe01095.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01095.jsonl
# [sbe01096] https://www.sacred-texts.com/hin/sbe01/sbe01096.htm → 26 lines
# [OK] Saved 26 units → data/upanishads_sbe/sbe01096.jsonl
# [sbe01097] https://www.sacred-texts.com/hin/sbe01/sbe01097.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe01097.jsonl
# [sbe01098] https://www.sacred-texts.com/hin/sbe01/sbe01098.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01098.jsonl
# [sbe01099] https://www.sacred-texts.com/hin/sbe01/sbe01099.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01099.jsonl
# [sbe01100] https://www.sacred-texts.com/hin/sbe01/sbe01100.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01100.jsonl
# [sbe01101] https://www.sacred-texts.com/hin/sbe01/sbe01101.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01101.jsonl
# [sbe01102] https://www.sacred-texts.com/hin/sbe01/sbe01102.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01102.jsonl
# [sbe01103] https://www.sacred-texts.com/hin/sbe01/sbe01103.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01103.jsonl
# [sbe01104] https://www.sacred-texts.com/hin/sbe01/sbe01104.htm → 32 lines
# [OK] Saved 32 units → data/upanishads_sbe/sbe01104.jsonl
# [sbe01105] https://www.sacred-texts.com/hin/sbe01/sbe01105.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01105.jsonl
# [sbe01106] https://www.sacred-texts.com/hin/sbe01/sbe01106.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01106.jsonl
# [sbe01107] https://www.sacred-texts.com/hin/sbe01/sbe01107.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01107.jsonl
# [sbe01108] https://www.sacred-texts.com/hin/sbe01/sbe01108.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01108.jsonl
# [sbe01109] https://www.sacred-texts.com/hin/sbe01/sbe01109.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01109.jsonl
# [sbe01110] https://www.sacred-texts.com/hin/sbe01/sbe01110.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01110.jsonl
# [sbe01111] https://www.sacred-texts.com/hin/sbe01/sbe01111.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01111.jsonl
# [sbe01112] https://www.sacred-texts.com/hin/sbe01/sbe01112.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01112.jsonl
# [sbe01113] https://www.sacred-texts.com/hin/sbe01/sbe01113.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01113.jsonl
# [sbe01114] https://www.sacred-texts.com/hin/sbe01/sbe01114.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01114.jsonl
# [sbe01115] https://www.sacred-texts.com/hin/sbe01/sbe01115.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01115.jsonl
# [sbe01116] https://www.sacred-texts.com/hin/sbe01/sbe01116.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01116.jsonl
# [sbe01117] https://www.sacred-texts.com/hin/sbe01/sbe01117.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01117.jsonl
# [sbe01118] https://www.sacred-texts.com/hin/sbe01/sbe01118.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01118.jsonl
# [sbe01119] https://www.sacred-texts.com/hin/sbe01/sbe01119.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01119.jsonl
# [sbe01120] https://www.sacred-texts.com/hin/sbe01/sbe01120.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01120.jsonl
# [sbe01121] https://www.sacred-texts.com/hin/sbe01/sbe01121.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01121.jsonl
# [sbe01122] https://www.sacred-texts.com/hin/sbe01/sbe01122.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01122.jsonl
# [sbe01123] https://www.sacred-texts.com/hin/sbe01/sbe01123.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01123.jsonl
# [sbe01124] https://www.sacred-texts.com/hin/sbe01/sbe01124.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01124.jsonl
# [sbe01125] https://www.sacred-texts.com/hin/sbe01/sbe01125.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01125.jsonl
# [sbe01126] https://www.sacred-texts.com/hin/sbe01/sbe01126.htm → 28 lines
# [OK] Saved 28 units → data/upanishads_sbe/sbe01126.jsonl
# [sbe01127] https://www.sacred-texts.com/hin/sbe01/sbe01127.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01127.jsonl
# [sbe01128] https://www.sacred-texts.com/hin/sbe01/sbe01128.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01128.jsonl
# [sbe01129] https://www.sacred-texts.com/hin/sbe01/sbe01129.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01129.jsonl
# [sbe01130] https://www.sacred-texts.com/hin/sbe01/sbe01130.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01130.jsonl
# [sbe01131] https://www.sacred-texts.com/hin/sbe01/sbe01131.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01131.jsonl
# [sbe01132] https://www.sacred-texts.com/hin/sbe01/sbe01132.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01132.jsonl
# [sbe01133] https://www.sacred-texts.com/hin/sbe01/sbe01133.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01133.jsonl
# [sbe01134] https://www.sacred-texts.com/hin/sbe01/sbe01134.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01134.jsonl
# [sbe01135] https://www.sacred-texts.com/hin/sbe01/sbe01135.htm → 17 lines
# [OK] Saved 17 units → data/upanishads_sbe/sbe01135.jsonl
# [sbe01136] https://www.sacred-texts.com/hin/sbe01/sbe01136.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01136.jsonl
# [sbe01137] https://www.sacred-texts.com/hin/sbe01/sbe01137.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01137.jsonl
# [sbe01138] https://www.sacred-texts.com/hin/sbe01/sbe01138.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01138.jsonl
# [sbe01139] https://www.sacred-texts.com/hin/sbe01/sbe01139.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01139.jsonl
# [sbe01140] https://www.sacred-texts.com/hin/sbe01/sbe01140.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01140.jsonl
# [sbe01141] https://www.sacred-texts.com/hin/sbe01/sbe01141.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01141.jsonl
# [sbe01142] https://www.sacred-texts.com/hin/sbe01/sbe01142.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01142.jsonl
# [sbe01143] https://www.sacred-texts.com/hin/sbe01/sbe01143.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01143.jsonl
# [sbe01144] https://www.sacred-texts.com/hin/sbe01/sbe01144.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01144.jsonl
# [sbe01145] https://www.sacred-texts.com/hin/sbe01/sbe01145.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01145.jsonl
# [sbe01146] https://www.sacred-texts.com/hin/sbe01/sbe01146.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01146.jsonl
# [sbe01147] https://www.sacred-texts.com/hin/sbe01/sbe01147.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01147.jsonl
# [sbe01148] https://www.sacred-texts.com/hin/sbe01/sbe01148.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01148.jsonl
# [sbe01149] https://www.sacred-texts.com/hin/sbe01/sbe01149.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01149.jsonl
# [sbe01150] https://www.sacred-texts.com/hin/sbe01/sbe01150.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01150.jsonl
# [sbe01151] https://www.sacred-texts.com/hin/sbe01/sbe01151.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01151.jsonl
# [sbe01152] https://www.sacred-texts.com/hin/sbe01/sbe01152.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01152.jsonl
# [sbe01153] https://www.sacred-texts.com/hin/sbe01/sbe01153.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01153.jsonl
# [sbe01154] https://www.sacred-texts.com/hin/sbe01/sbe01154.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01154.jsonl
# [sbe01155] https://www.sacred-texts.com/hin/sbe01/sbe01155.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01155.jsonl
# [sbe01156] https://www.sacred-texts.com/hin/sbe01/sbe01156.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe01156.jsonl
# [sbe01157] https://www.sacred-texts.com/hin/sbe01/sbe01157.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01157.jsonl
# [sbe01158] https://www.sacred-texts.com/hin/sbe01/sbe01158.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01158.jsonl
# [sbe01159] https://www.sacred-texts.com/hin/sbe01/sbe01159.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01159.jsonl
# [sbe01160] https://www.sacred-texts.com/hin/sbe01/sbe01160.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01160.jsonl
# [sbe01161] https://www.sacred-texts.com/hin/sbe01/sbe01161.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01161.jsonl
# [sbe01162] https://www.sacred-texts.com/hin/sbe01/sbe01162.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01162.jsonl
# [sbe01163] https://www.sacred-texts.com/hin/sbe01/sbe01163.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01163.jsonl
# [sbe01164] https://www.sacred-texts.com/hin/sbe01/sbe01164.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01164.jsonl
# [sbe01165] https://www.sacred-texts.com/hin/sbe01/sbe01165.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01165.jsonl
# [sbe01166] https://www.sacred-texts.com/hin/sbe01/sbe01166.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe01166.jsonl
# [sbe01167] https://www.sacred-texts.com/hin/sbe01/sbe01167.htm → 17 lines
# [OK] Saved 17 units → data/upanishads_sbe/sbe01167.jsonl
# [sbe01168] https://www.sacred-texts.com/hin/sbe01/sbe01168.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01168.jsonl
# [sbe01169] https://www.sacred-texts.com/hin/sbe01/sbe01169.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01169.jsonl
# [sbe01170] https://www.sacred-texts.com/hin/sbe01/sbe01170.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01170.jsonl
# [sbe01171] https://www.sacred-texts.com/hin/sbe01/sbe01171.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01171.jsonl
# [sbe01172] https://www.sacred-texts.com/hin/sbe01/sbe01172.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01172.jsonl
# [sbe01173] https://www.sacred-texts.com/hin/sbe01/sbe01173.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01173.jsonl
# [sbe01174] https://www.sacred-texts.com/hin/sbe01/sbe01174.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe01174.jsonl
# [sbe01175] https://www.sacred-texts.com/hin/sbe01/sbe01175.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe01175.jsonl
# [sbe01176] https://www.sacred-texts.com/hin/sbe01/sbe01176.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01176.jsonl
# [sbe01177] https://www.sacred-texts.com/hin/sbe01/sbe01177.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01177.jsonl
# [sbe01178] https://www.sacred-texts.com/hin/sbe01/sbe01178.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01178.jsonl
# [sbe01179] https://www.sacred-texts.com/hin/sbe01/sbe01179.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01179.jsonl
# [sbe01180] https://www.sacred-texts.com/hin/sbe01/sbe01180.htm → 27 lines
# [OK] Saved 27 units → data/upanishads_sbe/sbe01180.jsonl
# [sbe01181] https://www.sacred-texts.com/hin/sbe01/sbe01181.htm → 26 lines
# [OK] Saved 26 units → data/upanishads_sbe/sbe01181.jsonl
# [sbe01182] https://www.sacred-texts.com/hin/sbe01/sbe01182.htm → 24 lines
# [OK] Saved 24 units → data/upanishads_sbe/sbe01182.jsonl
# [sbe01183] https://www.sacred-texts.com/hin/sbe01/sbe01183.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe01183.jsonl
# [sbe01184] https://www.sacred-texts.com/hin/sbe01/sbe01184.htm → 30 lines
# [OK] Saved 30 units → data/upanishads_sbe/sbe01184.jsonl
# [sbe01185] https://www.sacred-texts.com/hin/sbe01/sbe01185.htm → 60 lines
# [OK] Saved 60 units → data/upanishads_sbe/sbe01185.jsonl
# [sbe01186] https://www.sacred-texts.com/hin/sbe01/sbe01186.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe01186.jsonl
# [sbe01187] https://www.sacred-texts.com/hin/sbe01/sbe01187.htm → 33 lines
# [OK] Saved 33 units → data/upanishads_sbe/sbe01187.jsonl
# [sbe01188] https://www.sacred-texts.com/hin/sbe01/sbe01188.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01188.jsonl
# [sbe01189] https://www.sacred-texts.com/hin/sbe01/sbe01189.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01189.jsonl
# [sbe01190] https://www.sacred-texts.com/hin/sbe01/sbe01190.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01190.jsonl
# [sbe01191] https://www.sacred-texts.com/hin/sbe01/sbe01191.htm → 37 lines
# [OK] Saved 37 units → data/upanishads_sbe/sbe01191.jsonl
# [sbe01192] https://www.sacred-texts.com/hin/sbe01/sbe01192.htm → 25 lines
# [OK] Saved 25 units → data/upanishads_sbe/sbe01192.jsonl
# [sbe01193] https://www.sacred-texts.com/hin/sbe01/sbe01193.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe01193.jsonl
# [sbe01194] https://www.sacred-texts.com/hin/sbe01/sbe01194.htm → 28 lines
# [OK] Saved 28 units → data/upanishads_sbe/sbe01194.jsonl
# [sbe01195] https://www.sacred-texts.com/hin/sbe01/sbe01195.htm → 28 lines
# [OK] Saved 28 units → data/upanishads_sbe/sbe01195.jsonl
# [sbe01196] https://www.sacred-texts.com/hin/sbe01/sbe01196.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe01196.jsonl
# [sbe01197] https://www.sacred-texts.com/hin/sbe01/sbe01197.htm → 73 lines
# [OK] Saved 73 units → data/upanishads_sbe/sbe01197.jsonl
# [sbe01198] https://www.sacred-texts.com/hin/sbe01/sbe01198.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe01198.jsonl
# [sbe01199] https://www.sacred-texts.com/hin/sbe01/sbe01199.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01199.jsonl
# [sbe01200] https://www.sacred-texts.com/hin/sbe01/sbe01200.htm → 34 lines
# [OK] Saved 34 units → data/upanishads_sbe/sbe01200.jsonl
# [sbe01201] https://www.sacred-texts.com/hin/sbe01/sbe01201.htm → 28 lines
# [OK] Saved 28 units → data/upanishads_sbe/sbe01201.jsonl
# [sbe01202] https://www.sacred-texts.com/hin/sbe01/sbe01202.htm → 24 lines
# [OK] Saved 24 units → data/upanishads_sbe/sbe01202.jsonl
# [sbe01203] https://www.sacred-texts.com/hin/sbe01/sbe01203.htm → 25 lines
# [OK] Saved 25 units → data/upanishads_sbe/sbe01203.jsonl
# [sbe01204] https://www.sacred-texts.com/hin/sbe01/sbe01204.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe01204.jsonl
# [sbe01205] https://www.sacred-texts.com/hin/sbe01/sbe01205.htm → 34 lines
# [OK] Saved 34 units → data/upanishads_sbe/sbe01205.jsonl
# [sbe01206] https://www.sacred-texts.com/hin/sbe01/sbe01206.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01206.jsonl
# [sbe01207] https://www.sacred-texts.com/hin/sbe01/sbe01207.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe01207.jsonl
# [sbe01208] https://www.sacred-texts.com/hin/sbe01/sbe01208.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01208.jsonl
# [sbe01209] https://www.sacred-texts.com/hin/sbe01/sbe01209.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe01209.jsonl
# [sbe01210] https://www.sacred-texts.com/hin/sbe01/sbe01210.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe01210.jsonl
# [sbe01211] https://www.sacred-texts.com/hin/sbe01/sbe01211.htm → 25 lines
# [OK] Saved 25 units → data/upanishads_sbe/sbe01211.jsonl
# [sbe01212] https://www.sacred-texts.com/hin/sbe01/sbe01212.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01212.jsonl
# [sbe01213] https://www.sacred-texts.com/hin/sbe01/sbe01213.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01213.jsonl
# [sbe01214] https://www.sacred-texts.com/hin/sbe01/sbe01214.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01214.jsonl
# [sbe01215] https://www.sacred-texts.com/hin/sbe01/sbe01215.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe01215.jsonl
# [sbe01216] https://www.sacred-texts.com/hin/sbe01/sbe01216.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe01216.jsonl
# [sbe01217] https://www.sacred-texts.com/hin/sbe01/sbe01217.htm → 28 lines
# [OK] Saved 28 units → data/upanishads_sbe/sbe01217.jsonl
# [sbe01218] https://www.sacred-texts.com/hin/sbe01/sbe01218.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe01218.jsonl
# [sbe01219] https://www.sacred-texts.com/hin/sbe01/sbe01219.htm → 30 lines
# [OK] Saved 30 units → data/upanishads_sbe/sbe01219.jsonl
# [sbe01220] https://www.sacred-texts.com/hin/sbe01/sbe01220.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01220.jsonl
# [sbe01221] https://www.sacred-texts.com/hin/sbe01/sbe01221.htm → 24 lines
# [OK] Saved 24 units → data/upanishads_sbe/sbe01221.jsonl
# [sbe01222] https://www.sacred-texts.com/hin/sbe01/sbe01222.htm → 35 lines
# [OK] Saved 35 units → data/upanishads_sbe/sbe01222.jsonl
# [sbe01223] https://www.sacred-texts.com/hin/sbe01/sbe01223.htm → 16 lines
# [OK] Saved 16 units → data/upanishads_sbe/sbe01223.jsonl
# [sbe01224] https://www.sacred-texts.com/hin/sbe01/sbe01224.htm → 33 lines
# [OK] Saved 33 units → data/upanishads_sbe/sbe01224.jsonl
# [sbe01225] https://www.sacred-texts.com/hin/sbe01/sbe01225.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe01225.jsonl
# [sbe01226] https://www.sacred-texts.com/hin/sbe01/sbe01226.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe01226.jsonl
# [sbe01227] https://www.sacred-texts.com/hin/sbe01/sbe01227.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe01227.jsonl
# [sbe01228] https://www.sacred-texts.com/hin/sbe01/sbe01228.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01228.jsonl
# [sbe01229] https://www.sacred-texts.com/hin/sbe01/sbe01229.htm → 45 lines
# [OK] Saved 45 units → data/upanishads_sbe/sbe01229.jsonl
# [sbe01230] https://www.sacred-texts.com/hin/sbe01/sbe01230.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe01230.jsonl
# [sbe01231] https://www.sacred-texts.com/hin/sbe01/sbe01231.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe01231.jsonl
# [sbe01232] https://www.sacred-texts.com/hin/sbe01/sbe01232.htm → 31 lines
# [OK] Saved 31 units → data/upanishads_sbe/sbe01232.jsonl
# [sbe01233] https://www.sacred-texts.com/hin/sbe01/sbe01233.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe01233.jsonl
# [sbe01234] https://www.sacred-texts.com/hin/sbe01/sbe01234.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe01234.jsonl
# [sbe01235] https://www.sacred-texts.com/hin/sbe01/sbe01235.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01235.jsonl
# [sbe01236] https://www.sacred-texts.com/hin/sbe01/sbe01236.htm → 40 lines
# [OK] Saved 40 units → data/upanishads_sbe/sbe01236.jsonl
# [sbe01237] https://www.sacred-texts.com/hin/sbe01/sbe01237.htm → 21 lines
# [OK] Saved 21 units → data/upanishads_sbe/sbe01237.jsonl
# [sbe01238] https://www.sacred-texts.com/hin/sbe01/sbe01238.htm → 50 lines
# [OK] Saved 50 units → data/upanishads_sbe/sbe01238.jsonl
# [sbe01239] https://www.sacred-texts.com/hin/sbe01/sbe01239.htm → 65 lines
# [OK] Saved 65 units → data/upanishads_sbe/sbe01239.jsonl
# [sbe01240] https://www.sacred-texts.com/hin/sbe01/sbe01240.htm → 82 lines
# [OK] Saved 82 units → data/upanishads_sbe/sbe01240.jsonl
# [sbe01241] https://www.sacred-texts.com/hin/sbe01/sbe01241.htm → 40 lines
# [OK] Saved 40 units → data/upanishads_sbe/sbe01241.jsonl
# [sbe01242] https://www.sacred-texts.com/hin/sbe01/sbe01242.htm → 117 lines
# [OK] Saved 117 units → data/upanishads_sbe/sbe01242.jsonl
# [sbe01243] https://www.sacred-texts.com/hin/sbe01/sbe01243.htm → 85 lines
# [OK] Saved 85 units → data/upanishads_sbe/sbe01243.jsonl
# [sbe15000] https://www.sacred-texts.com/hin/sbe15/sbe15000.htm → 2 lines
# [OK] Saved 2 units → data/upanishads_sbe/sbe15000.jsonl
# [sbe15001] https://www.sacred-texts.com/hin/sbe15/sbe15001.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe15001.jsonl
# [sbe15002] https://www.sacred-texts.com/hin/sbe15/sbe15002.htm → 170 lines
# [OK] Saved 170 units → data/upanishads_sbe/sbe15002.jsonl
# [sbe15003] https://www.sacred-texts.com/hin/sbe15/sbe15003.htm → 39 lines
# [OK] Saved 39 units → data/upanishads_sbe/sbe15003.jsonl
# [sbe15004] https://www.sacred-texts.com/hin/sbe15/sbe15004.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe15004.jsonl
# [sbe15005] https://www.sacred-texts.com/hin/sbe15/sbe15005.htm → 38 lines
# [OK] Saved 38 units → data/upanishads_sbe/sbe15005.jsonl
# [sbe15006] https://www.sacred-texts.com/hin/sbe15/sbe15006.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe15006.jsonl
# [sbe15007] https://www.sacred-texts.com/hin/sbe15/sbe15007.htm → 77 lines
# [OK] Saved 77 units → data/upanishads_sbe/sbe15007.jsonl
# [sbe15008] https://www.sacred-texts.com/hin/sbe15/sbe15008.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15008.jsonl
# [sbe15009] https://www.sacred-texts.com/hin/sbe15/sbe15009.htm → 116 lines
# [OK] Saved 116 units → data/upanishads_sbe/sbe15009.jsonl
# [sbe15010] https://www.sacred-texts.com/hin/sbe15/sbe15010.htm → 65 lines
# [OK] Saved 65 units → data/upanishads_sbe/sbe15010.jsonl
# [sbe15011] https://www.sacred-texts.com/hin/sbe15/sbe15011.htm → 53 lines
# [OK] Saved 53 units → data/upanishads_sbe/sbe15011.jsonl
# [sbe15012] https://www.sacred-texts.com/hin/sbe15/sbe15012.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe15012.jsonl
# [sbe15013] https://www.sacred-texts.com/hin/sbe15/sbe15013.htm → 25 lines
# [OK] Saved 25 units → data/upanishads_sbe/sbe15013.jsonl
# [sbe15014] https://www.sacred-texts.com/hin/sbe15/sbe15014.htm → 30 lines
# [OK] Saved 30 units → data/upanishads_sbe/sbe15014.jsonl
# [sbe15015] https://www.sacred-texts.com/hin/sbe15/sbe15015.htm → 48 lines
# [OK] Saved 48 units → data/upanishads_sbe/sbe15015.jsonl
# [sbe15016] https://www.sacred-texts.com/hin/sbe15/sbe15016.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe15016.jsonl
# [sbe15017] https://www.sacred-texts.com/hin/sbe15/sbe15017.htm → 32 lines
# [OK] Saved 32 units → data/upanishads_sbe/sbe15017.jsonl
# [sbe15018] https://www.sacred-texts.com/hin/sbe15/sbe15018.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe15018.jsonl
# [sbe15019] https://www.sacred-texts.com/hin/sbe15/sbe15019.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe15019.jsonl
# [sbe15020] https://www.sacred-texts.com/hin/sbe15/sbe15020.htm → 22 lines
# [OK] Saved 22 units → data/upanishads_sbe/sbe15020.jsonl
# [sbe15021] https://www.sacred-texts.com/hin/sbe15/sbe15021.htm → 27 lines
# [OK] Saved 27 units → data/upanishads_sbe/sbe15021.jsonl
# [sbe15022] https://www.sacred-texts.com/hin/sbe15/sbe15022.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15022.jsonl
# [sbe15023] https://www.sacred-texts.com/hin/sbe15/sbe15023.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15023.jsonl
# [sbe15024] https://www.sacred-texts.com/hin/sbe15/sbe15024.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe15024.jsonl
# [sbe15025] https://www.sacred-texts.com/hin/sbe15/sbe15025.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe15025.jsonl
# [sbe15026] https://www.sacred-texts.com/hin/sbe15/sbe15026.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe15026.jsonl
# [sbe15027] https://www.sacred-texts.com/hin/sbe15/sbe15027.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15027.jsonl
# [sbe15028] https://www.sacred-texts.com/hin/sbe15/sbe15028.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15028.jsonl
# [sbe15029] https://www.sacred-texts.com/hin/sbe15/sbe15029.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe15029.jsonl
# [sbe15030] https://www.sacred-texts.com/hin/sbe15/sbe15030.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15030.jsonl
# [sbe15031] https://www.sacred-texts.com/hin/sbe15/sbe15031.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe15031.jsonl
# [sbe15032] https://www.sacred-texts.com/hin/sbe15/sbe15032.htm → 10 lines
# [OK] Saved 10 units → data/upanishads_sbe/sbe15032.jsonl
# [sbe15033] https://www.sacred-texts.com/hin/sbe15/sbe15033.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15033.jsonl
# [sbe15034] https://www.sacred-texts.com/hin/sbe15/sbe15034.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe15034.jsonl
# [sbe15035] https://www.sacred-texts.com/hin/sbe15/sbe15035.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15035.jsonl
# [sbe15036] https://www.sacred-texts.com/hin/sbe15/sbe15036.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15036.jsonl
# [sbe15037] https://www.sacred-texts.com/hin/sbe15/sbe15037.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe15037.jsonl
# [sbe15038] https://www.sacred-texts.com/hin/sbe15/sbe15038.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15038.jsonl
# [sbe15039] https://www.sacred-texts.com/hin/sbe15/sbe15039.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15039.jsonl
# [sbe15040] https://www.sacred-texts.com/hin/sbe15/sbe15040.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe15040.jsonl
# [sbe15041] https://www.sacred-texts.com/hin/sbe15/sbe15041.htm → 76 lines
# [OK] Saved 76 units → data/upanishads_sbe/sbe15041.jsonl
# [sbe15042] https://www.sacred-texts.com/hin/sbe15/sbe15042.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15042.jsonl
# [sbe15043] https://www.sacred-texts.com/hin/sbe15/sbe15043.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15043.jsonl
# [sbe15044] https://www.sacred-texts.com/hin/sbe15/sbe15044.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15044.jsonl
# [sbe15045] https://www.sacred-texts.com/hin/sbe15/sbe15045.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15045.jsonl
# [sbe15046] https://www.sacred-texts.com/hin/sbe15/sbe15046.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15046.jsonl
# [sbe15047] https://www.sacred-texts.com/hin/sbe15/sbe15047.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe15047.jsonl
# [sbe15048] https://www.sacred-texts.com/hin/sbe15/sbe15048.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15048.jsonl
# [sbe15049] https://www.sacred-texts.com/hin/sbe15/sbe15049.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15049.jsonl
# [sbe15050] https://www.sacred-texts.com/hin/sbe15/sbe15050.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15050.jsonl
# [sbe15051] https://www.sacred-texts.com/hin/sbe15/sbe15051.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe15051.jsonl
# [sbe15052] https://www.sacred-texts.com/hin/sbe15/sbe15052.htm → 18 lines
# [OK] Saved 18 units → data/upanishads_sbe/sbe15052.jsonl
# [sbe15053] https://www.sacred-texts.com/hin/sbe15/sbe15053.htm → 17 lines
# [OK] Saved 17 units → data/upanishads_sbe/sbe15053.jsonl
# [sbe15054] https://www.sacred-texts.com/hin/sbe15/sbe15054.htm → 91 lines
# [OK] Saved 91 units → data/upanishads_sbe/sbe15054.jsonl
# [sbe15055] https://www.sacred-texts.com/hin/sbe15/sbe15055.htm → 53 lines
# [OK] Saved 53 units → data/upanishads_sbe/sbe15055.jsonl
# [sbe15056] https://www.sacred-texts.com/hin/sbe15/sbe15056.htm → 72 lines
# [OK] Saved 72 units → data/upanishads_sbe/sbe15056.jsonl
# [sbe15057] https://www.sacred-texts.com/hin/sbe15/sbe15057.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe15057.jsonl
# [sbe15058] https://www.sacred-texts.com/hin/sbe15/sbe15058.htm → 48 lines
# [OK] Saved 48 units → data/upanishads_sbe/sbe15058.jsonl
# [sbe15059] https://www.sacred-texts.com/hin/sbe15/sbe15059.htm → 19 lines
# [OK] Saved 19 units → data/upanishads_sbe/sbe15059.jsonl
# [sbe15060] https://www.sacred-texts.com/hin/sbe15/sbe15060.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe15060.jsonl
# [sbe15061] https://www.sacred-texts.com/hin/sbe15/sbe15061.htm → 64 lines
# [OK] Saved 64 units → data/upanishads_sbe/sbe15061.jsonl
# [sbe15062] https://www.sacred-texts.com/hin/sbe15/sbe15062.htm → 43 lines
# [OK] Saved 43 units → data/upanishads_sbe/sbe15062.jsonl
# [sbe15063] https://www.sacred-texts.com/hin/sbe15/sbe15063.htm → 73 lines
# [OK] Saved 73 units → data/upanishads_sbe/sbe15063.jsonl
# [sbe15064] https://www.sacred-texts.com/hin/sbe15/sbe15064.htm → 58 lines
# [OK] Saved 58 units → data/upanishads_sbe/sbe15064.jsonl
# [sbe15065] https://www.sacred-texts.com/hin/sbe15/sbe15065.htm → 31 lines
# [OK] Saved 31 units → data/upanishads_sbe/sbe15065.jsonl
# [sbe15066] https://www.sacred-texts.com/hin/sbe15/sbe15066.htm → 11 lines
# [OK] Saved 11 units → data/upanishads_sbe/sbe15066.jsonl
# [sbe15067] https://www.sacred-texts.com/hin/sbe15/sbe15067.htm → 14 lines
# [OK] Saved 14 units → data/upanishads_sbe/sbe15067.jsonl
# [sbe15068] https://www.sacred-texts.com/hin/sbe15/sbe15068.htm → 13 lines
# [OK] Saved 13 units → data/upanishads_sbe/sbe15068.jsonl
# [sbe15069] https://www.sacred-texts.com/hin/sbe15/sbe15069.htm → 27 lines
# [OK] Saved 27 units → data/upanishads_sbe/sbe15069.jsonl
# [sbe15070] https://www.sacred-texts.com/hin/sbe15/sbe15070.htm → 41 lines
# [OK] Saved 41 units → data/upanishads_sbe/sbe15070.jsonl
# [sbe15071] https://www.sacred-texts.com/hin/sbe15/sbe15071.htm → 31 lines
# [OK] Saved 31 units → data/upanishads_sbe/sbe15071.jsonl
# [sbe15072] https://www.sacred-texts.com/hin/sbe15/sbe15072.htm → 193 lines
# [OK] Saved 193 units → data/upanishads_sbe/sbe15072.jsonl
# [sbe15073] https://www.sacred-texts.com/hin/sbe15/sbe15073.htm → 87 lines
# [OK] Saved 87 units → data/upanishads_sbe/sbe15073.jsonl
# [sbe15074] https://www.sacred-texts.com/hin/sbe15/sbe15074.htm → 30 lines
# [OK] Saved 30 units → data/upanishads_sbe/sbe15074.jsonl
# [sbe15075] https://www.sacred-texts.com/hin/sbe15/sbe15075.htm → 112 lines
# [OK] Saved 112 units → data/upanishads_sbe/sbe15075.jsonl
# [sbe15076] https://www.sacred-texts.com/hin/sbe15/sbe15076.htm → 86 lines
# [OK] Saved 86 units → data/upanishads_sbe/sbe15076.jsonl
# [sbe15077] https://www.sacred-texts.com/hin/sbe15/sbe15077.htm → 42 lines
# [OK] Saved 42 units → data/upanishads_sbe/sbe15077.jsonl
# [sbe15078] https://www.sacred-texts.com/hin/sbe15/sbe15078.htm → 75 lines
# [OK] Saved 75 units → data/upanishads_sbe/sbe15078.jsonl
# [sbe15079] https://www.sacred-texts.com/hin/sbe15/sbe15079.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15079.jsonl
# [sbe15080] https://www.sacred-texts.com/hin/sbe15/sbe15080.htm → 8 lines
# [OK] Saved 8 units → data/upanishads_sbe/sbe15080.jsonl
# [sbe15081] https://www.sacred-texts.com/hin/sbe15/sbe15081.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15081.jsonl
# [sbe15082] https://www.sacred-texts.com/hin/sbe15/sbe15082.htm → 7 lines
# [OK] Saved 7 units → data/upanishads_sbe/sbe15082.jsonl
# [sbe15083] https://www.sacred-texts.com/hin/sbe15/sbe15083.htm → 12 lines
# [OK] Saved 12 units → data/upanishads_sbe/sbe15083.jsonl
# [sbe15084] https://www.sacred-texts.com/hin/sbe15/sbe15084.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15084.jsonl
# [sbe15085] https://www.sacred-texts.com/hin/sbe15/sbe15085.htm → 4 lines
# [OK] Saved 4 units → data/upanishads_sbe/sbe15085.jsonl
# [sbe15086] https://www.sacred-texts.com/hin/sbe15/sbe15086.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15086.jsonl
# [sbe15087] https://www.sacred-texts.com/hin/sbe15/sbe15087.htm → 3 lines
# [OK] Saved 3 units → data/upanishads_sbe/sbe15087.jsonl
# [sbe15088] https://www.sacred-texts.com/hin/sbe15/sbe15088.htm → 5 lines
# [OK] Saved 5 units → data/upanishads_sbe/sbe15088.jsonl
# [sbe15089] https://www.sacred-texts.com/hin/sbe15/sbe15089.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15089.jsonl
# [sbe15090] https://www.sacred-texts.com/hin/sbe15/sbe15090.htm → 6 lines
# [OK] Saved 6 units → data/upanishads_sbe/sbe15090.jsonl
# [sbe15091] https://www.sacred-texts.com/hin/sbe15/sbe15091.htm → 9 lines
# [OK] Saved 9 units → data/upanishads_sbe/sbe15091.jsonl
# [sbe15092] https://www.sacred-texts.com/hin/sbe15/sbe15092.htm → 31 lines
# [OK] Saved 31 units → data/upanishads_sbe/sbe15092.jsonl
# [sbe15093] https://www.sacred-texts.com/hin/sbe15/sbe15093.htm → 15 lines
# [OK] Saved 15 units → data/upanishads_sbe/sbe15093.jsonl
# [sbe15094] https://www.sacred-texts.com/hin/sbe15/sbe15094.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe15094.jsonl
# [sbe15095] https://www.sacred-texts.com/hin/sbe15/sbe15095.htm → 50 lines
# [OK] Saved 50 units → data/upanishads_sbe/sbe15095.jsonl
# [sbe15096] https://www.sacred-texts.com/hin/sbe15/sbe15096.htm → 62 lines
# [OK] Saved 62 units → data/upanishads_sbe/sbe15096.jsonl
# [sbe15097] https://www.sacred-texts.com/hin/sbe15/sbe15097.htm → 107 lines
# [OK] Saved 107 units → data/upanishads_sbe/sbe15097.jsonl
# [sbe15098] https://www.sacred-texts.com/hin/sbe15/sbe15098.htm → 137 lines
# [OK] Saved 137 units → data/upanishads_sbe/sbe15098.jsonl
# [sbe15099] https://www.sacred-texts.com/hin/sbe15/sbe15099.htm → 87 lines
# [OK] Saved 87 units → data/upanishads_sbe/sbe15099.jsonl
# [sbe15100] https://www.sacred-texts.com/hin/sbe15/sbe15100.htm → 69 lines
# [OK] Saved 69 units → data/upanishads_sbe/sbe15100.jsonl
# [sbe15101] https://www.sacred-texts.com/hin/sbe15/sbe15101.htm → 47 lines
# [OK] Saved 47 units → data/upanishads_sbe/sbe15101.jsonl
# [sbe15102] https://www.sacred-texts.com/hin/sbe15/sbe15102.htm → 66 lines
# [OK] Saved 66 units → data/upanishads_sbe/sbe15102.jsonl
# [sbe15103] https://www.sacred-texts.com/hin/sbe15/sbe15103.htm → 60 lines
# [OK] Saved 60 units → data/upanishads_sbe/sbe15103.jsonl
# [sbe15104] https://www.sacred-texts.com/hin/sbe15/sbe15104.htm → 52 lines
# [OK] Saved 52 units → data/upanishads_sbe/sbe15104.jsonl
# [sbe15105] https://www.sacred-texts.com/hin/sbe15/sbe15105.htm → 76 lines
# [OK] Saved 76 units → data/upanishads_sbe/sbe15105.jsonl
# [sbe15106] https://www.sacred-texts.com/hin/sbe15/sbe15106.htm → 39 lines
# [OK] Saved 39 units → data/upanishads_sbe/sbe15106.jsonl
# [sbe15107] https://www.sacred-texts.com/hin/sbe15/sbe15107.htm → 29 lines
# [OK] Saved 29 units → data/upanishads_sbe/sbe15107.jsonl
# [sbe15108] https://www.sacred-texts.com/hin/sbe15/sbe15108.htm → 27 lines
# [OK] Saved 27 units → data/upanishads_sbe/sbe15108.jsonl
# [sbe15109] https://www.sacred-texts.com/hin/sbe15/sbe15109.htm → 26 lines
# [OK] Saved 26 units → data/upanishads_sbe/sbe15109.jsonl
# [sbe15110] https://www.sacred-texts.com/hin/sbe15/sbe15110.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe15110.jsonl
# [sbe15111] https://www.sacred-texts.com/hin/sbe15/sbe15111.htm → 20 lines
# [OK] Saved 20 units → data/upanishads_sbe/sbe15111.jsonl
# [sbe15112] https://www.sacred-texts.com/hin/sbe15/sbe15112.htm → 35 lines
# [OK] Saved 35 units → data/upanishads_sbe/sbe15112.jsonl
# [sbe15113] https://www.sacred-texts.com/hin/sbe15/sbe15113.htm → 60 lines
# [OK] Saved 60 units → data/upanishads_sbe/sbe15113.jsonl
# [sbe15114] https://www.sacred-texts.com/hin/sbe15/sbe15114.htm → 42 lines
# [OK] Saved 42 units → data/upanishads_sbe/sbe15114.jsonl
# [sbe15115] https://www.sacred-texts.com/hin/sbe15/sbe15115.htm → 36 lines
# [OK] Saved 36 units → data/upanishads_sbe/sbe15115.jsonl
# [sbe15116] https://www.sacred-texts.com/hin/sbe15/sbe15116.htm → 23 lines
# [OK] Saved 23 units → data/upanishads_sbe/sbe15116.jsonl
# [sbe15117] https://www.sacred-texts.com/hin/sbe15/sbe15117.htm → 309 lines
# [OK] Saved 309 units → data/upanishads_sbe/sbe15117.jsonl
# [sbe15118] https://www.sacred-texts.com/hin/sbe15/sbe15118.htm → 67 lines
# [OK] Saved 67 units → data/upanishads_sbe/sbe15118.jsonl

# %%
# ===== Rig Veda (Griffith) → download, parse, and save JSONL per book =====
import re, json, time, pathlib, requests, urllib.parse
from bs4 import BeautifulSoup, NavigableString

# Index with links to Books (Mandala I..X). If this ever changes, set BOOK_LINKS manually.
RV_INDEX = "https://www.sacred-texts.com/hin/rigveda/index.htm"
OUT_DIR = pathlib.Path("data/rigveda_griffith")
OUT_DIR.mkdir(parents=True, exist_ok=True)

HDRS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

def fetch(url, tries=3, sleep=0.7):
    for _ in range(tries):
        r = requests.get(url, headers=HDRS, timeout=30)
        if r.ok:
            return r.text
        time.sleep(sleep)
    r.raise_for_status()

def abs_url(base, href):
    return urllib.parse.urljoin(base, href)

def clean(s: str) -> str:
    return re.sub(r"\s+", " ", s).strip(" \u00a0")

LEAD_NUM = re.compile(r"^\s*(\d{1,3})\s*[\.\):\-–—]?\s*(.*)$", re.U | re.I)

def get_links_from(url, pattern=None, same_dir=True):
    html = fetch(url)
    soup = BeautifulSoup(html, "lxml")
    base_dir = url.rsplit("/",1)[0] + "/"
    out = []
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if not href.lower().endswith(".htm"): continue
        full = abs_url(url, href)
        if same_dir and not full.startswith(base_dir): continue
        if pattern and not re.search(pattern, full, re.I): continue
        if "index" in full.lower(): continue
        out.append(full)
    return sorted(set(out))

# 1) From the index, find Book pages (mandala pages)
book_pages = get_links_from(RV_INDEX, pattern=r"(book|bk|mandala|rv|rvi|rvs)")
print("Found candidate Book pages:", len(book_pages))
if not book_pages:
    print("No book pages discovered from index. You may set BOOK_PAGES manually.")

# 2) From each Book page, find Hymn pages; then parse verses inside each hymn page
def parse_hymn_page(html):
    soup = BeautifulSoup(html, "lxml")
    for t in soup.select("script, style, header, footer, nav"): t.decompose()
    body = soup.find("body") or soup
    lines = []
    # Many hymn pages number verses as "1. text", "2. text", etc.
    # We'll split on <br> and <p> and capture leading numbers.
    verse_buffer = []
    for el in body.find_all(["p","div","blockquote","center"]):
        buf = []
        for node in el.descendants:
            if isinstance(node, NavigableString):
                buf.append(str(node))
            elif getattr(node, "name", None) == "br":
                txt = clean(" ".join(buf))
                buf = []
                if not txt: continue
                m = LEAD_NUM.match(txt)
                if m:
                    # start a new numbered verse
                    lines.append((int(m.group(1)), clean(m.group(2))))
                elif lines:
                    # continuation of current verse
                    vno, prev = lines[-1]
                    lines[-1] = (vno, clean(prev + " " + txt))
        tail = clean(" ".join(buf))
        if tail:
            m = LEAD_NUM.match(tail)
            if m:
                lines.append((int(m.group(1)), clean(m.group(2))))
            elif lines:
                vno, prev = lines[-1]
                lines[-1] = (vno, clean(prev + " " + tail))
    # de-dup and prune
    seen, out = set(), []
    for vno, txt in lines:
        key = (vno, txt)
        if key in seen: continue
        seen.add(key)
        if txt and len(txt) > 1:
            out.append((vno, txt))
    return out

def parse_book(book_url, book_num_guess=None):
    # discover hymn pages from the book page
    hymn_pages = get_links_from(book_url, pattern=r"(hymn|hym|rv|rvi|rvs|bk|book)", same_dir=False)
    print(f"Book page {book_url} → {len(hymn_pages)} hymn pages")
    # guess book number from URL/title if not provided
    book_num = book_num_guess
    if book_num is None:
        m = re.search(r"book\s*(\d+)", fetch(book_url), re.I)
        if m: book_num = int(m.group(1))
    if book_num is None:
        # last-resort heuristic
        m = re.search(r"/(\d{1,2})[^/]*\.htm$", book_url)
        book_num = int(m.group(1)) if m else 0

    all_rows = []
    hymn_idx = 0
    for hymn_url in hymn_pages:
        hymn_idx += 1
        try:
            html = fetch(hymn_url)
            verses = parse_hymn_page(html)
            if not verses:
                # fallback: treat whole page as one verse
                txt = clean(BeautifulSoup(html, "lxml").get_text(" ", strip=True))
                if txt:
                    verses = [(1, txt)]
            for vno, text in verses:
                all_rows.append((book_num, hymn_idx, vno, text, hymn_url))
        except Exception as e:
            print("  !! hymn fail:", hymn_url, "→", e)
    return all_rows

# Parse each discovered book page and write per-book JSONL
total = 0
for i, b in enumerate(book_pages, start=1):
    rows = parse_book(b, book_num_guess=i if i<=10 else None)
    if not rows:
        print("!! empty book:", b)
        continue
    out_path = OUT_DIR / f"rv_book{i:02d}.jsonl"
    with open(out_path, "w", encoding="utf-8") as f:
        for (book, hymn, verse, text, src) in rows:
            item = {
                "id": f"RV.{book}.{hymn}.{verse}",
                "collection": "Vedas",
                "work": "Rig Veda",
                "book": book, "hymn": hymn, "verse": verse,
                "canonical_ref": f"RV {book}.{hymn}.{verse}",
                "translator": "R. T. H. Griffith — Public Domain",
                "year": 1896,
                "license": "Public Domain",
                "source_url": src,
                "lang": "en",
                "text": text
            }
            f.write(json.dumps(item, ensure_ascii=False) + "\n")
            total += 1
    print(f"[OK] Book {i:02d}: {len(rows)} verses → {out_path}")

print("Total Rig Veda units written:", total)
# Out:
# Found candidate Book pages: 11
# Book page https://www.sacred-texts.com/hin/rigveda/rv01000.htm → 2 hymn pages
# [OK] Book 01: 10 verses → data/rigveda_griffith/rv_book01.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi01.htm → 194 hymn pages
# [OK] Book 02: 1982 verses → data/rigveda_griffith/rv_book02.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi02.htm → 46 hymn pages
# [OK] Book 03: 436 verses → data/rigveda_griffith/rv_book03.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi03.htm → 65 hymn pages
# [OK] Book 04: 620 verses → data/rigveda_griffith/rv_book04.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi04.htm → 61 hymn pages
# [OK] Book 05: 592 verses → data/rigveda_griffith/rv_book05.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi05.htm → 90 hymn pages
# [OK] Book 06: 729 verses → data/rigveda_griffith/rv_book06.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi06.htm → 78 hymn pages
# [OK] Book 07: 770 verses → data/rigveda_griffith/rv_book07.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi07.htm → 107 hymn pages
# [OK] Book 08: 843 verses → data/rigveda_griffith/rv_book08.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi08.htm → 106 hymn pages
# [OK] Book 09: 1719 verses → data/rigveda_griffith/rv_book09.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi09.htm → 117 hymn pages
# [OK] Book 10: 1109 verses → data/rigveda_griffith/rv_book10.jsonl
# Book page https://www.sacred-texts.com/hin/rigveda/rvi10.htm → 193 hymn pages
# [OK] Book 11: 1752 verses → data/rigveda_griffith/rv_book11.jsonl
# Total Rig Veda units written: 10562

# %% [markdown]
# ## 2. Save embeddings of these 3 scripture

# %%
# ===== Build embeddings for all shards under data/** =====
import os, json, pathlib, numpy as np
from sentence_transformers import SentenceTransformer

ROOT = pathlib.Path("data")
EMB_MODEL = "sentence-transformers/all-MiniLM-L6-v2"  # 384-d
embedder = SentenceTransformer(EMB_MODEL)

def read_jsonl(p: pathlib.Path):
    with p.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            yield json.loads(line)

def build_folder(folder: pathlib.Path):
    # Collect all .jsonl files within this folder (non-recursive)
    jsonls = sorted([p for p in folder.glob("*.jsonl") if p.is_file()])
    if not jsonls:
        return None
    print(f"\n[Shard] {folder}  ({len(jsonls)} JSONL files)")
    items, texts = [], []
    for j in jsonls:
        for rec in read_jsonl(j):
            items.append(rec)
            texts.append(rec.get("text",""))
    if not items:
        print("  (no items)"); return None

    # Embed (batched), normalize, and save Float16
    print(f"  Embedding {len(items)} units …")
    embs = embedder.encode(texts, normalize_embeddings=True, batch_size=128, show_progress_bar=True)
    embs = np.asarray(embs, dtype=np.float32)
    dim = embs.shape[1]
    embs_f16 = embs.astype(np.float16)

    # Save combined chunks.jsonl and embeddings.f16.bin in the folder
    combined_chunks = folder / "chunks.jsonl"
    with combined_chunks.open("w", encoding="utf-8") as f:
        for rec in items:
            f.write(json.dumps(rec, ensure_ascii=False) + "\n")

    emb_bin = folder / "embeddings.f16.bin"
    embs_f16.tofile(emb_bin)

    # Write a small manifest
    manifest = {
        "count": len(items),
        "dim": int(dim),
        "model": EMB_MODEL,
        "files": [str(p.name) for p in jsonls],
        "combined_chunks": combined_chunks.name,
        "embeddings_bin": emb_bin.name,
    }
    with (folder / "manifest.json").open("w", encoding="utf-8") as f:
        json.dump(manifest, f, indent=2)
    print(f"  → Saved {len(items)} chunks, dim={dim}  to {folder.name}/")
    return manifest

# Walk immediate subfolders of data/ and build each shard
manifests = {}
for sub in sorted([p for p in ROOT.glob("*") if p.is_dir()]):
    m = build_folder(sub)
    if m:
        manifests[sub.name] = m

# Top-level manifest for the whole corpus
with (ROOT / "manifest.json").open("w", encoding="utf-8") as f:
    json.dump(manifests, f, indent=2)
print("\n[Done] Manifests written for shards:", ", ".join(manifests.keys()))
# Out:
# [Shard] data/gita_arnold  (1 JSONL files)
#   Embedding 2436 units …
# Batches:   0%|          | 0/20 [00:00<?, ?it/s]
#   → Saved 2436 chunks, dim=384  to gita_arnold/
#
# [Shard] data/rigveda_griffith  (11 JSONL files)
#   Embedding 10562 units …
# Batches:   0%|          | 0/83 [00:00<?, ?it/s]
#   → Saved 10562 chunks, dim=384  to rigveda_griffith/
#
# [Shard] data/upanishads_sbe  (365 JSONL files)
#   Embedding 8412 units …
# Batches:   0%|          | 0/66 [00:00<?, ?it/s]
#   → Saved 8412 chunks, dim=384  to upanishads_sbe/
#
# [Done] Manifests written for shards: gita_arnold, rigveda_griffith, upanishads_sbe

# %% [markdown]
# ## 3) Build Hybrid Index (BM25 + MiniLM embeddings)

# %%
# Tokenization for BM25
def tokenize(s: str) -> List[str]:
    return s.lower().split()

bm25 = BM25Okapi([tokenize(c["text"]) for c in CORPUS])

# Sentence embeddings
EMB_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(EMB_MODEL_NAME)
doc_texts = [c["text"] for c in CORPUS]
doc_emb = embedder.encode(doc_texts, normalize_embeddings=True, show_progress_bar=False)
doc_emb = np.asarray(doc_emb, dtype=np.float32)
doc_emb.shape
# Out:
# (2436, 384)

# %% [markdown]
# ## 4) Retrieval helpers

# %%
from typing import List, Dict, Any, Tuple

def embed_query(q: str) -> np.ndarray:
    return embedder.encode([q], normalize_embeddings=True)[0].astype(np.float32)

def cosine_topk(q_emb: np.ndarray, mat: np.ndarray, k: int = 5) -> List[Tuple[int, float]]:
    # mat: (N, D)
    scores = (mat @ q_emb).tolist()
    idxs = list(range(len(scores)))
    idxs.sort(key=lambda i: scores[i], reverse=True)
    return [(i, scores[i]) for i in idxs[:k]]

def bm25_topk(q: str, k: int = 5) -> List[Tuple[int, float]]:
    scores = bm25.get_scores(tokenize(q))
    idxs = list(range(len(scores)))
    idxs.sort(key=lambda i: scores[i], reverse=True)
    return [(i, float(scores[i])) for i in idxs[:k]]

def hybrid_retrieve(q: str, k_vec=5, k_bm=5, top_final=5) -> List[Dict[str, Any]]:
    q_emb = embed_query(q)
    vec = cosine_topk(q_emb, doc_emb, k=k_vec)
    bow = bm25_topk(q, k=k_bm)
    # merge by index with max score normalization
    combined = {}
    for i, s in vec:
        combined[i] = max(combined.get(i, 0.0), float(s))
    # Normalize BM25 scores
    if bow:
        max_bm = max(s for _, s in bow) or 1.0
        for i, s in bow:
            combined[i] = max(combined.get(i, 0.0), float(s)/max_bm * 0.9)  # weight BM25 a bit
    ranked = sorted(combined.items(), key=lambda x: x[1], reverse=True)[:top_final]
    results = [CORPUS[i] | {"_score": float(sc)} for i, sc in ranked]
    return results

# quick smoke test
hybrid_retrieve("What is nishkama karma?")
# Out:
# [{'canon_id': 'BG 8.3',
#   'work': 'Bhagavad Gita',
#   'chapter': 8,
#   'verse': 3,
#   'translator': 'Sir Edwin Arnold (1885) — Public Domain',
#   'license': 'Public Domain',
#   'source': 'https://www.sacred-texts.com/hin/gita/bg08.htm',
#   'text': 'Thy work, the KARMA? Tell me what it is',
#   '_score': 0.9},
#  {'canon_id': 'BG 13.37',
#   'work': 'Bhagavad Gita',
#   'chapter': 13,
#   'verse': 37,
#   'translator': 'Sir Edwin Arnold (1885) — Public Domain',
#   'license': 'Public Domain',
#   'source': 'https://www.sacred-texts.com/hin/gita/bg13.htm',
#   'text': 'And what is otherwise is ignorance!',
#   '_score': 0.556723896743809},
#  {'canon_id': 'BG 8.12',
#   'work': 'Bhagavad Gita',
#   'chapter': 8,
#   'verse': 12,
#   'translator': 'Sir Edwin Arnold (1885) — Public Domain',
#   'license': 'Public Domain',
#   'source': 'https://www.sacred-texts.com/hin/gita/bg08.htm',
#   'text': 'Causing all life to live, is KARMA called:',
#   '_score': 0.5285435914993286},
#  {'canon_id': 'BG 2.250',
#   'work': 'Bhagavad Gita',
#   'chapter': 2,
#   'verse': 250,
#   'translator': 'Sir Edwin Arnold (1885) — Public Domain',
#   'license': 'Public Domain',
#   'source': 'https://www.sacred-texts.com/hin/gita/bg02.htm',
#   'text': 'Shows wisdom perfect. What is midnight-gloom',
#   '_score': 0.4812447118947686},
#  {'canon_id': 'BG 2.101',
#   'work': 'Bhagavad Gita',
#   'chapter': 2,
#   'verse': 101,
#   'translator': 'Sir Edwin Arnold (1885) — Public Domain',
#   'license': 'Public Domain',
#   'source': 'https://www.sacred-texts.com/hin/gita/bg02.htm',
#   'text': 'What is there sorrowful herein, dear Prince?',
#   '_score': 0.45085643694205874}]

# %% [markdown]
# ## 5) Answer using Groq Llama (with citations), fallback to extractive

# %%
GROQ_URL = "https://api.groq.com/openai/v1/chat/completions"

SYSTEM_PROMPT = '''You are a Hindu scripture assistant.
Follow these rules strictly:
1. Answer using ONLY the provided passages.
2. After each claim, include citations like `BG 2.47` or `BG 3.19`.
3. If the answer is not directly supported, say "Not found in current corpus."
4. Be concise and neutral about doctrinal schools; mention when views differ.
'''

def build_context(retrieved: List[Dict[str, Any]]) -> str:
    blocks = []
    for r in retrieved:
        cid = r.get("canon_id","?")
        txt = r["text"]
        trn = r.get("translator","")
        blocks.append(f"[{cid}] {txt} (Translator: {trn})")
    return "\n\n".join(blocks)

def extractive_answer(query: str, retrieved: List[Dict[str, Any]]) -> Dict[str, Any]:
    # Simple rule-based summary of top chunks
    if not retrieved:
        return {"answer":"Not found in current corpus.", "citations":[]}
    snippets = []
    cites = []
    for r in retrieved[:3]:
        snippets.append(f"- {r['text']} ({r['canon_id']})")
        cites.append(r["canon_id"])
    answer = (
        "Here are relevant passages:\n" + "\n".join(snippets) + "\n\n"
        "Summary: Acting without attachment to outcomes; focusing on one’s duty; disciplined action. "
        "(citations: " + ", ".join(cites) + ")"
    )
    return {"answer": answer, "citations": cites}

def answer_query(query: str, k_vec=6, k_bm=6, top_final=5, temperature=0.2) -> Dict[str, Any]:
    retrieved = hybrid_retrieve(query, k_vec=k_vec, k_bm=k_bm, top_final=top_final)
    context = build_context(retrieved)
    if not GROQ_API_KEY:
        print("No GROQ_API_KEY found; using extractive fallback.\n")
        return extractive_answer(query, retrieved)

    payload = {
        "model": GROQ_MODEL,
        "messages": [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": f"Query: {query}\n\nPassages:\n{context}\n\nAnswer with citations."}
        ],
        "temperature": temperature,
        "max_tokens": 600,
        "stream": False
    }
    try:
        resp = requests.post(
            GROQ_URL,
            headers={
                "Authorization": f"Bearer {GROQ_API_KEY}",
                "Content-Type": "application/json"
            },
            json=payload,
            timeout=60
        )
        resp.raise_for_status()
        data = resp.json()
        text = data["choices"][0]["message"]["content"].strip()
        # naive citation scrape for demo
        cites = [c["canon_id"] for c in retrieved if c["canon_id"] in text]
        return {"answer": text, "citations": cites, "retrieved": retrieved}
    except Exception as e:
        print("Groq call failed, falling back to extractive. Error:\n", e)
        return extractive_answer(query, retrieved)

# %% [markdown]
# ## 6) Quick Smoke Tests

# %%
tests = [
    "What does gita say about parents?",
    "Explain nishkama karma with references.",
    "Is it ok to be attached?",
]

for q in tests:
    print("="*80)
    print("Q:", q)
    out = answer_query(q)
    print("\nAnswer:\n", out["answer"])
    if "retrieved" in out:
        print("\nTop sources:")
        for r in out["retrieved"]:
            print(f"  - {r['canon_id']}  score={r['_score']:.3f}")
# Out:
# ================================================================================
# Q: What does gita say about parents?
#
# Answer:
#  The Bhagavad Gita does not directly mention parents in the provided passages. However, it emphasizes the importance of selfless actions and the concept of sacrifice, which can be applied to one's relationships with family members, including parents.
#
# It is worth noting that in Hindu tradition, parents are considered sacred and are often referred to as "guru" or "pitru" (ancestors). The Gita's emphasis on selfless actions and sacrifice can be seen as a way of honoring and respecting one's parents.
#
# Not found in current corpus for direct mention of parents.
#
# Top sources:
#   - BG 4.78  score=0.900
#   - BG 1.2  score=0.592
#   - BG 18.7  score=0.517
#   - BG 17.58  score=0.486
#   - BG 2.83  score=0.459
# ================================================================================
# Q: Explain nishkama karma with references.
#
# Answer:
#  Nishkama karma refers to selfless action, where one performs their duties without attachment to the outcome. This concept is described in the Bhagavad Gita as follows:
#
# BG 5.36 states, "With life, with heart, with mind,- nay, with the help" (BG 5.36). This suggests that one should perform their duties with their entire being, without any attachment.
#
# BG 5.84 further clarifies that those who have effaced their sins, doubts, and have pure hearts, perform their duties without attachment. "With sins effaced, with doubts at end, with hearts" (BG 5.84).
#
# BG 15.43 describes the process of nishkama karma, stating that one should feed the fire of sacrifice with both outward and inward breath. "With outward and with inward breath, to feed" (BG 15.43).
#
# BG 8.3 asks, "Thy work, the KARMA? Tell me what it is" (BG 8.3), implying that one should understand their duties and perform them without attachment.
#
# BG 8.12 describes the purpose of karma, stating that it is called karma when it causes all life to live. "Causing all life to live, is KARMA called" (BG 8.12).
#
# These passages collectively suggest that nishkama karma involves performing one's duties without attachment, with a pure heart, and for the benefit of all life.
#
# Top sources:
#   - BG 8.12  score=0.900
#   - BG 8.3  score=0.585
#   - BG 5.36  score=0.584
#   - BG 5.84  score=0.544
#   - BG 15.43  score=0.478
# ================================================================================
# Q: Is it ok to be attached?
#
# Answer:
#  It is not recommended to be attached.
#
# BG 2.18 states that even if being attached were worse, it is still better to be attached than to be detached and miserable. However, this does not necessarily mean attachment is desirable.
#
# BG 4.7 implies that attachment is a hindrance to spiritual growth, as it is something that must be overcome.
#
# BG 6.144 suggests that detachment from worldly attachments is difficult to achieve, but this does not mean attachment is desirable.
#
# BG 3.107 implies that attachment to worldly things is a form of opposition to the law of nature.
#
# BG 9.78 states that even if one is attached, one can still achieve spiritual growth through prayer and fasting, but this does not necessarily mean attachment is desirable.
#
# Therefore, it is not recommended to be attached.
#
# BG 2.47 states that the one who has control over the senses is a yogi, and the one who has not is not. This implies that attachment is a hindrance to being a yogi.
#
# BG 3.19 states that the yogi who has control over the senses is not attached to anything, and this is the state of the self-realized.
#
# Top sources:
#   - BG 2.18  score=0.900
#   - BG 4.7  score=0.786
#   - BG 6.144  score=0.753
#   - BG 3.107  score=0.711
#   - BG 9.78  score=0.711
